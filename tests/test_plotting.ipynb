# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
from lid_driven_cavity import postprocessing

# %%
h = np.flip(np.logspace(0.001, 10.0, 20))
orders = [1, 2, 3, 4]

# %%
for order in orders:
    postprocessing.plot_convergence(h, h**order, [1, 2, 3, 4])
